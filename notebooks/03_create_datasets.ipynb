# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

random.seed(42)

PATH_TO_DATA = '../data/'

# %%
verbatim_file = PATH_TO_DATA + 'processed/single_csv/verbatim.csv'
verbatim_df = pd.read_csv(verbatim_file)
verbatim_df.tail(3)
# Out:
#              gbifID   eventDate continent         country  \
# 3674057  3905003113  2022-08-13    Europe         Germany
# 3674058  3907062141  2022-08-13    Europe     Netherlands
# 3674059  4889724145  2022-08-14    Europe  United Kingdom
#
#                stateProvince  decimalLatitude  decimalLongitude  \
# 3674057  Nordrhein-Westfalen        51.186953          6.072675
# 3674058              Drenthe        53.000000          6.400000
# 3674059   England - Cheshire        53.221595         -2.512970
#
#            scientificName vernacularName  higherClassification       family
# 3674057   Lycaena phlaeas   Small Copper   Animalia|Lycaenidae   Lycaenidae
# 3674058  Pyronia tithonus     Gatekeeper  Animalia|Nymphalidae  Nymphalidae
# 3674059   Triodia sylvina   Orange Swift   Animalia|Hepialidae   Hepialidae

# %%
multimedia_file = PATH_TO_DATA + 'processed/single_csv/multimedia.csv'
multimedia_df = pd.read_csv(multimedia_file)
multimedia_df.tail(3)
# Out:
#              gbifID      format                                   identifier
# 4271285  4891549309  image/jpeg  https://observation.org/photos/91183706.jpg
# 4271286  4891549354  image/jpeg  https://observation.org/photos/91196424.jpg
# 4271287  4891549377  image/jpeg  https://observation.org/photos/91209494.jpg

# %%
species_counts = verbatim_df['scientificName'].value_counts()

# %% [markdown]
# ### Creating testing dataset (top20max50)
# - 20 species with most occurrences
# - 50 images per species
# - Total images: 1000

# %%
species_for_testing_ds = species_counts.head(20).keys()
species_for_testing_ds
# Out:
# Index(['Pararge aegeria', 'Vanessa atalanta', 'Noctua pronuba', 'Aglais io',
#        'Lycaena phlaeas', 'Polyommatus icarus', 'Autographa gamma',
#        'Pieris napi', 'Maniola jurtina', 'Pieris rapae', 'Polygonia c-album',
#        'Cydalima perspectalis', 'Coenonympha pamphilus', 'Aglais urticae',
#        'Gonepteryx rhamni', 'Peribatodes rhomboidaria', 'Araschnia levana',
#        'Celastrina argiolus', 'Camptogramma bilineata', 'Vanessa cardui'],
#       dtype='object', name='scientificName')

# %%
gbifID_blacklist = [1966132886, 4459520332] # entering gbifIDs which match images with poor quality
selected_species = species_counts.head(20).keys()
selected_data = {'gbifID': [], 'scientificName': []}

for species in selected_species:
    species_ids = verbatim_df[verbatim_df['scientificName'] == species]['gbifID'].tolist()

    valid_species_ids = [id for id in species_ids if id not in gbifID_blacklist]
    
    if len(valid_species_ids) >= 50:
        selected = random.sample(species_ids, 50)
    
    # Füge die ausgewählten IDs zur Liste hinzu
    for gbifID in selected:
        selected_data['gbifID'].append(gbifID)
        selected_data['scientificName'].append(species)


selected_df = pd.DataFrame(selected_data)

output_file = PATH_TO_DATA + 'processed/testing_dataset_top20max50.csv'
# selected_df.to_csv(output_file, index=False)

# %% [markdown]
# ### Creating testing dataset (top589max3000)
# - 589 species with most occurrences (all above 1k)
# - maximum of 3000 images per species (randomly selected)
# - Total images: ~1.3 million

# %%
full_df = pd.merge(verbatim_df, multimedia_df, on='gbifID')
print(full_df.shape)
full_df.tail(3)
# Out:
# (4271288, 13)
#              gbifID   eventDate continent         country  \
# 4271285  3905003113  2022-08-13    Europe         Germany
# 4271286  3907062141  2022-08-13    Europe     Netherlands
# 4271287  4889724145  2022-08-14    Europe  United Kingdom
#
#                stateProvince  decimalLatitude  decimalLongitude  \
# 4271285  Nordrhein-Westfalen        51.186953          6.072675
# 4271286              Drenthe        53.000000          6.400000
# 4271287   England - Cheshire        53.221595         -2.512970
#
#            scientificName vernacularName  higherClassification       family  \
# 4271285   Lycaena phlaeas   Small Copper   Animalia|Lycaenidae   Lycaenidae
# 4271286  Pyronia tithonus     Gatekeeper  Animalia|Nymphalidae  Nymphalidae
# 4271287   Triodia sylvina   Orange Swift   Animalia|Hepialidae   Hepialidae
#
#              format                                   identifier
# 4271285  image/jpeg  https://observation.org/photos/56429659.jpg
# 4271286  image/jpeg  https://observation.org/photos/56466702.jpg
# 4271287  image/jpeg  https://observation.org/photos/56494589.jpg

# %%
full_df = full_df.drop_duplicates(subset=['gbifID']) # reduce to single occ per gbifID
print(full_df.shape)
# Out:
# (3674060, 13)

# %%
full_df_grouped = full_df.groupby('scientificName') # Group by 'scientificName'
filtered_dfs = []

MAX_AMOUNT = 3000
MIN_AMOUNT = 1000

for name, group in full_df_grouped:
    sample_size = len(group)
    if sample_size >= MAX_AMOUNT:
        sampled = group.sample(n=MAX_AMOUNT, random_state=42) # classes with more than 5000 samples get reduced to 5000
        filtered_dfs.append(sampled)
    elif MIN_AMOUNT <= sample_size < MAX_AMOUNT: # classes between 1000 and 5000 stay unchanged
        filtered_dfs.append(group)
    # Classes with less than 1000 samples are skipped

# Concatenate the filtered DataFrames
final_df = pd.concat(filtered_dfs)
print(final_df.shape)
final_df['scientificName'].value_counts()
# Out:
# (1388034, 13)
# scientificName
# Udea ferrugalis                       3000
# Tyria jacobaeae                       3000
# Zygaena filipendulae                  3000
# Triodia sylvina                       3000
# Acrobasis tumidana                    3000
# Abrostola triplasia                   3000
# Yponomeuta spec.                      3000
# Acentria ephemerella                  3000
# Aglais urticae                        3000
# Aglais io                             3000
# Agapeta hamana                        3000
# Adela reaumurella                     3000
# Acronicta tridens / psi               3000
# Acronicta rumicis                     3000
# Vanessa atalanta                      3000
# Parapoynx stratiotata                 3000
# Papilio machaon                       3000
# Pandemis cerasana                     3000
# Lomaspilis marginata                  3000
# Anania hortulata                      3000
# Agriphila straminella                 3000
# Agriopis marginaria                   3000
# Agriopis leucophaearia                3000
# Amblyptilia acanthadactyla            3000
# Alucita hexadactyla                   3000
# Alsophila aescularia                  3000
# Aleimma loeflingiana                  3000
# Agrotis segetum                       3000
# Miltochrista miniata                  3000
# Aporia crataegi                       3000
# Apoda limacodes                       3000
# Thyatira batis                        3000
# Thaumetopoea processionea             3000
# Agrotis puta                          3000
# Agrotis ipsilon                       3000
# Agrotis exclamationis                 3000
# Aphomia sociella                      3000
# Aphantopus hyperantus                 3000
# Apamea monoglypha                     3000
# Anthophila fabriciana                 3000
# Anthocharis cardamines                3000
# Anarta trifolii                       3000
# Biston betularia                      3000
# Axylia putris                         3000
# Autographa gamma                      3000
# Atolmis rubricollis                   3000
# Aricia agestis                        3000
# Argynnis paphia                       3000
# Arctia caja                           3000
# Archips xylosteana                    3000
# Archips podana                        3000
# Araschnia levana                      3000
# Limenitis reducta                     3000
# Limenitis camilla                     3000
# Ligdia adustata                       3000
# Laspeyria flexula                     3000
# Laothoe populi                        3000
# Lampides boeticus                     3000
# Lacanobia oleracea                    3000
# Issoria lathonia                      3000
# Iphiclides podalirius                 3000
# Idaea subsericeata                    3000
# Idaea seriata                         3000
# Idaea rusticata                       3000
# Callophrys rubi                       3000
# Calliteara pudibunda                  3000
# Cacoecimorpha pronubana               3000
# Cabera pusaria                        3000
# Spilosoma lutea                       3000
# Spilosoma lubricipeda                 3000
# Synaphe punctalis                     3000
# Subacronicta megacephala              3000
# Stegania trimaculata                  3000
# Cabera exanthemata                    3000
# Bupalus piniaria                      3000
# Brintesia circe                       3000
# Charanyca trigrammica                 3000
# Celypha striana                       3000
# Celypha lacunana                      3000
# Celastrina argiolus                   3000
# Catoptria pinella                     3000
# Atethmia centrago                     3000
# Carterocephalus palaemon              3000
# Carcina quercana                      3000
# Carcharodus alceae                    3000
# Caradrina morpheus                    3000
# Caradrina clavipalpis                 3000
# Camptogramma bilineata                3000
# Campaea margaritaria                  3000
# Catocala nupta                        3000
# Cataclysta lemnata                    3000
# Coenonympha pamphilus                 3000
# Coenonympha arcania                   3000
# Clepsis dumicolana                    3000
# Clepsis consimilana                   3000
# Chrysoteuchia culmella                3000
# Chloroclystis v-ata                   3000
# Chloroclysta siterata                 3000
# Chiasmia clathrata                    3000
# Spilonota ocellana                    3000
# Sphinx pinastri                       3000
# Sphinx ligustri                       3000
# Speyeria aglaja                       3000
# Pasiphila rectangulata                3000
# Pararge aegeria                       3000
# Hedya nubiferana                      3000
# Idaea fuscovenosa                     3000
# Idaea dimidiata                       3000
# Idaea biselata                        3000
# Idaea aversata                        3000
# Hypsopygia costalis                   3000
# Hypomecis punctinalis                 3000
# Hypena rostralis                      3000
# Hypena proboscidalis                  3000
# Lasiommata megera                     3000
# Melanargia galathea                   3000
# Maniola jurtina                       3000
# Mamestra brassicae                    3000
# Macroglossum stellatarum              3000
# Noctua fimbriata                      3000
# Noctua comes                          3000
# Nemophora degeerella                  3000
# Mythimna vitellina                    3000
# Mythimna albipuncta                   3000
# Mormo maura                           3000
# Mimas tiliae                          3000
# Catoptria falsella                    3000
# Cydia amplana                         3000
# Cydalima perspectalis                 3000
# Cyclophora punctaria                  3000
# Cyclophora linearia                   3000
# Cyaniris semiargus                    3000
# Crambus lathoniellus                  3000
# Cosmia trapezina                      3000
# Conistra vaccinii                     3000
# Conistra rubiginosa                   3000
# Colotois pennaria                     3000
# Colostygia pectinataria               3000
# Colocasia coryli                      3000
# Colias crocea                         3000
# Crambus perlella                      3000
# Crambus pascuella                     3000
# Diurnea fagella                       3000
# Ditula angustiorana                   3000
# Diarsia rubi                          3000
# Diaphora mendica                      3000
# Diachrysia chrysitis                  3000
# Deltote pygarga                       3000
# Deltote bankiana                      3000
# Deilephila porcellus                  3000
# Scoliopteryx libatrix                 3000
# Rivula sericealis                     3000
# Rhodometra sacraria                   3000
# Rhizedra lutosa                       3000
# Pyronia tithonus                      3000
# Eilema griseola                       3000
# Eilema complana                       3000
# Ectropis crepuscularia                3000
# Dysstroma truncata                    3000
# Dypterygia scabriuscula               3000
# Dryobotodes eremita                   3000
# Drymonia querna                       3000
# Drepana falcataria                    3000
# Cryphia algae                         3000
# Crocallis elinguaria                  3000
# Craniophora ligustri                  3000
# Macaria liturata                      3000
# Macaria alternata                     3000
# Lythria cruentaria                    3000
# Lysandra coridon                      3000
# Lysandra bellargus                    3000
# Lymantria dispar                      3000
# Lycaena tityrus                       3000
# Lycaena phlaeas                       3000
# Luperina testacea                     3000
# Ourapteryx sambucaria                 3000
# Orthosia incerta                      3000
# Peridea anceps                        3000
# Orthosia cerasi                       3000
# Opisthograptis luteolata              3000
# Operophtera brumata                   3000
# Oncocera semirubella                  3000
# Oligia strigilis                      3000
# Oligia fasciuncula                    3000
# Olethreutes arcuella                  3000
# Ochropleura plecta                    3000
# Mesoligia furuncula                   3000
# Mesapamea secalis / secalella         3000
# Melitaea phoebe                       3000
# Melitaea didyma                       3000
# Melitaea cinxia                       3000
# Deilephila elpenor                    3000
# Cydia splendana                       3000
# Cydia pomonella                       3000
# Erannis defoliaria                    3000
# Epirrita spec.                        3000
# Epirrhoe alternata                    3000
# Ennomos erosaria                      3000
# Endrosis sarcitrella                  3000
# Endotricha flammealis                 3000
# Emmelina monodactyla                  3000
# Ematurga atomaria                     3000
# Elophila nymphaeata                   3000
# Eilema sororcula                      3000
# Pyrausta despicata                    3000
# Pyrausta aurata                       3000
# Orthosia gothica                      3000
# Orthosia cruda                        3000
# Plutella xylostella                   3000
# Pyralis farinalis                     3000
# Ptilodon capucina                     3000
# Pterostoma palpina                    3000
# Pterophorus pentadactyla              3000
# Pseudopanthera macularia              3000
# Pseudoips prasinana                   3000
# Pontia daplidice                      3000
# Eudonia mercurella                    3000
# Euclidia glyphica                     3000
# Esperia sulphurella                   3000
# Erynnis tages                         3000
# Favonius quercus                      3000
# Eupsilia transversa                   3000
# Euplagia quadripunctaria              3000
# Eupithecia centaureata                3000
# Eupithecia abbreviata                 3000
# Polyommatus icarus                    3000
# Polygonia c-album                     3000
# Peribatodes rhomboidaria              3000
# Pelosia muscerda                      3000
# Hoplodrina octogenaria                3000
# Hoplodrina ambigua                    3000
# Hofmannophila pseudospretella         3000
# Hipparchia semele                     3000
# Hesperia comma                        3000
# Hemithea aestivaria                   3000
# Habrosyne pyritoides                  3000
# Gymnoscelis rufifasciata              3000
# Gonepteryx rhamni                     3000
# Phycita roborella                     3000
# Phragmatobia fuliginosa               3000
# Phlogophora meticulosa                3000
# Phigalia pilosaria                    3000
# Pheosia tremula                       3000
# Pheosia gnoma                         3000
# Phalera bucephala                     3000
# Perizoma alchemillata                 3000
# Plodia interpunctella                 3000
# Pleuroptya ruralis                    3000
# Plebejus argus                        3000
# Pieris rapae                          3000
# Pieris napi                           3000
# Pieris mannii                         3000
# Pieris brassicae                      3000
# Trachea atriplicis                    3000
# Tortrix viridana                      3000
# Timandra comae                        3000
# Thymelicus sylvestris                 3000
# Thymelicus lineola                    3000
# Agrochola lunosa                      3000
# Agrochola circellaris                 3000
# Agrius convolvuli                     3000
# Agriphila tristella                   3000
# Xestia xanthographa                   3000
# Xestia c-nigrum                       3000
# Xanthorhoe montanata                  3000
# Cerastis rubricosa                    1001
# Name: count, dtype: int64

# %%
# save dataset to file
# full_df.to_csv(PATH_TO_DATA + 'processed/dataset_full.csv', index=False)
# final_df.to_csv(PATH_TO_DATA + 'processed/dataset_top589_max3000.csv', index=False)

# %% [markdown]
# ### Create Datasets for CV and Baseline

# %%
top589_max3000_file = PATH_TO_DATA + 'processed/dataset_top589_max3000.csv'
top589_max3000_df = pd.read_csv(top589_max3000_file)
top589_max3000_df.head(3)
# Out:
#        gbifID   eventDate continent      country  stateProvince  \
# 0  3906248438  2022-06-13    Europe  Netherlands     Gelderland
# 1  3715637791  2018-06-15    Europe  Netherlands        Utrecht
# 2  3721642196  2021-07-03    Europe  Netherlands  Noord-Holland
#
#    decimalLatitude  decimalLongitude         scientificName vernacularName  \
# 0            52.20              6.05  Abraxas grossulariata         Magpie
# 1            52.20              4.85  Abraxas grossulariata         Magpie
# 2            53.05              4.80  Abraxas grossulariata         Magpie
#
#    higherClassification       family      format  \
# 0  Animalia|Geometridae  Geometridae  image/jpeg
# 1  Animalia|Geometridae  Geometridae  image/jpeg
# 2  Animalia|Geometridae  Geometridae  image/jpeg
#
#                                     identifier
# 0  https://observation.org/photos/52122202.jpg
# 1  https://observation.org/photos/17321218.jpg
# 2  https://observation.org/photos/38571328.jpg

# %%
dataset_configs = {
    'top277': (277, [3000, 2000, 1000, 500]), # (amount of classes, [amount of samples per species])
    'top387': (387, [2000, 1000, 500]),
    'top589': (589, [1000, 500])
}

for class_amount, sample_amounts in dataset_configs.values():
    selected_species = top589_max3000_df['scientificName'].value_counts().head(class_amount).keys() # first 277 classes have 3000 samples


    top277_max3000_df = top589_max3000_df[top589_max3000_df['scientificName'].isin(selected_species)]
    top277_max3000_df_grouped = top277_max3000_df.groupby('scientificName') # Group by 'scientificName'

    for amount in sample_amounts:
        filtered_dfs = []

        for name, group in top277_max3000_df_grouped:
            sampled = group.sample(n=amount, random_state=42)
            filtered_dfs.append(sampled)
        variation_df = pd.concat(filtered_dfs)
        print(f'Shape for dataset with {amount} samples for {class_amount} species: {variation_df.shape}')
        #if input(f'Enter 1 to save dataset_top{class_amount}_max{amount}.csv') == '1':
        variation_df.to_csv(PATH_TO_DATA + f'processed/resized_datasets/dataset_top{class_amount}_max{amount}.csv', index=False)
        print(f'Saved dataset_top{class_amount}_max{amount}.csv')
# Out:
# Shape for dataset with 3000 samples for 277 species: (831000, 13)
# Saved dataset_top277_max3000.csv
# Shape for dataset with 2000 samples for 277 species: (554000, 13)
# Saved dataset_top277_max2000.csv
# Shape for dataset with 1000 samples for 277 species: (277000, 13)
# Saved dataset_top277_max1000.csv
# Shape for dataset with 500 samples for 277 species: (138500, 13)
# Saved dataset_top277_max500.csv
# Shape for dataset with 2000 samples for 387 species: (774000, 13)
# Saved dataset_top387_max2000.csv
# Shape for dataset with 1000 samples for 387 species: (387000, 13)
# Saved dataset_top387_max1000.csv
# Shape for dataset with 500 samples for 387 species: (193500, 13)
# Saved dataset_top387_max500.csv
# Shape for dataset with 1000 samples for 589 species: (589000, 13)
# Saved dataset_top589_max1000.csv
# Shape for dataset with 500 samples for 589 species: (294500, 13)
# Saved dataset_top589_max500.csv
